# %% [markdown]
# # Step 3: make a map

# %% [markdown]
# ## Import dependencies

# %% [markdown]
# Code dependencies.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Markdown

# %% [markdown]
# Import the trip data file.

# %%
# Load the trip data file
df = pd.read_csv(Path("data/hub-pair-stats.csv").resolve())

df.sample(5)
# Out:
#                                              Hub Pair  Total Count  \
# 8   ('Municipal Parking Lot Lot# 7', 'Municipal Pa...           47
# 27      ('Metro North - Plaza', 'Spring St, Cofield')           12
# 48  ('Cronton Ave & Pleasantville Road', 'Spring &...            5
# 37                ('Spring & Waller', 'Wishnie Park')            8
# 38  ('Municipal Parking Lot Lot# 7', 'Ossining Pub...            8
#
#             Hub 1 Geolocation          Hub 2 Geolocation  Hub 1 Start Count  \
# 8   (41.1618223, -73.8629757)  (41.1618223, -73.8629757)                 47
# 27    (41.157844, -73.868112)  (41.1570899, -73.8640002)                  6
# 48  (41.1669377, -73.8497735)  (41.1593892, -73.8638232)                  3
# 37  (41.1593892, -73.8638232)  (41.1607067, -73.8477673)                  4
# 38  (41.1618223, -73.8629757)  (41.1642872, -73.8604165)                  4
#
#     Hub 2 Start Count  Single Hub
# 8                  47        True
# 27                  6       False
# 48                  2       False
# 37                  4       False
# 38                  4       False

# %%
df.sort_values(by="Total Count", ascending=False, inplace=True)
df.head(10)
# Out:
#                                             Hub Pair  Total Count  \
# 0                     ('Nelson park', 'Nelson park')          159
# 1  ('Arcadian Shopping Center', 'Municipal Parkin...          132
# 2             ('Metro North - Plaza', 'Nelson park')           92
# 3                   ('Wishnie Park', 'Wishnie Park')           86
# 4     ('Metro North - Plaza', 'Metro North - Plaza')           78
# 5       ('Spring St, Cofield', 'Spring St, Cofield')           59
# 6  ('Cronton Ave & Pleasantville Road', 'Metro No...           51
# 7               ('C Town Markets', 'C Town Markets')           48
# 8  ('Municipal Parking Lot Lot# 7', 'Municipal Pa...           47
# 9  ('Cronton Ave & Pleasantville Road', 'Cronton ...           46
#
#            Hub 1 Geolocation          Hub 2 Geolocation  Hub 1 Start Count  \
# 0  (41.1521048, -73.8623897)  (41.1521048, -73.8623897)                159
# 1   (41.1394616, -73.861803)  (41.1618223, -73.8629757)                 46
# 2    (41.157844, -73.868112)  (41.1521048, -73.8623897)                 34
# 3  (41.1607067, -73.8477673)  (41.1607067, -73.8477673)                 86
# 4    (41.157844, -73.868112)    (41.157844, -73.868112)                 78
# 5  (41.1570899, -73.8640002)  (41.1570899, -73.8640002)                 59
# 6  (41.1669377, -73.8497735)    (41.157844, -73.868112)                 15
# 7   (41.1653387, -73.856297)   (41.1653387, -73.856297)                 48
# 8  (41.1618223, -73.8629757)  (41.1618223, -73.8629757)                 47
# 9  (41.1669377, -73.8497735)  (41.1669377, -73.8497735)                 46
#
#    Hub 2 Start Count  Single Hub
# 0                159        True
# 1                 86       False
# 2                 58       False
# 3                 86        True
# 4                 78        True
# 5                 59        True
# 6                 36       False
# 7                 48        True
# 8                 47        True
# 9                 46        True

# %% [markdown]
# Import the hub addresses

# %%
addresses_df = pd.read_csv(Path("data/hub-locations.csv").resolve())
addresses_df = addresses_df.drop(columns=["OpenStreetMap Data"]) # drop the column with OSM data... we don't need it here.

addresses_df.sample(5)
# Out:
#                          Hub  \
# 0   Arcadian Shopping Center
# 4        Metro North - Plaza
# 6                Nelson park
# 9         Spring St, Cofield
# 10              Wishnie Park
#
#                                               Address  \
# 0   225-207 Albany Post Rd, Briarcliff Manor, NY 1...
# 4                      1 Secor Rd, Ossining, NY 10562
# 6                  20 Madison Ave, Ossining, NY 10562
# 9           Spring St & Broad Ave, Ossining, NY 10562
# 10     145-149 Orchard Rd, Briarcliff Manor, NY 10510
#
#                   Geolocation
# 0    (41.1394616, -73.861803)
# 4     (41.157844, -73.868112)
# 6   (41.1521048, -73.8623897)
# 9   (41.1570899, -73.8640002)
# 10  (41.1607067, -73.8477673)

# %%
# Add a 'Start Count' field to addresses_df
addresses_df['Start Count'] = addresses_df['Hub'].apply(
    lambda hub: df[df['Hub Pair'].str.contains(f"'{hub}'") & df['Hub Pair'].str.startswith(f"('{hub}'")]['Hub 1 Start Count'].sum()
)

addresses_df
# Out:
#                                  Hub  \
# 0           Arcadian Shopping Center
# 1                     C Town Markets
# 2   Cronton Ave & Pleasantville Road
# 3                      Market Square
# 4                Metro North - Plaza
# 5       Municipal Parking Lot Lot# 7
# 6                        Nelson park
# 7            Ossining Public Library
# 8                    Spring & Waller
# 9                 Spring St, Cofield
# 10                      Wishnie Park
#
#                                               Address  \
# 0   225-207 Albany Post Rd, Briarcliff Manor, NY 1...
# 1                  100 Croton Ave, Ossining, NY 10562
# 2   Croton Ave & Pleasantville Rd, Ossining, NY 10562
# 3                     160 Main St, Ossining, NY 10562
# 4                      1 Secor Rd, Ossining, NY 10562
# 5                 1-15 Leonard St, Ossining, NY 10562
# 6                  20 Madison Ave, Ossining, NY 10562
# 7                   53 Croton Ave, Ossining, NY 10562
# 8          Spring St & Waller Ave, Ossining, NY 10562
# 9           Spring St & Broad Ave, Ossining, NY 10562
# 10     145-149 Orchard Rd, Briarcliff Manor, NY 10510
#
#                   Geolocation  Start Count
# 0    (41.1394616, -73.861803)          166
# 1    (41.1653387, -73.856297)           95
# 2   (41.1669377, -73.8497735)           93
# 3   (41.1609922, -73.8627212)           50
# 4     (41.157844, -73.868112)          150
# 5   (41.1618223, -73.8629757)           66
# 6   (41.1521048, -73.8623897)          166
# 7   (41.1642872, -73.8604165)           51
# 8   (41.1593892, -73.8638232)           32
# 9   (41.1570899, -73.8640002)           59
# 10  (41.1607067, -73.8477673)           86

# %%
# Add a 'Start Count' field to addresses_df
addresses_df['End Count'] = addresses_df['Hub'].apply(
    lambda hub: df[df['Hub Pair'].str.contains(f", '{hub}'") & df['Hub Pair'].str.endswith(f"'{hub}')")]['Hub 2 Start Count'].sum()
)

addresses_df
# Out:
#                                  Hub  \
# 0           Arcadian Shopping Center
# 1                     C Town Markets
# 2   Cronton Ave & Pleasantville Road
# 3                      Market Square
# 4                Metro North - Plaza
# 5       Municipal Parking Lot Lot# 7
# 6                        Nelson park
# 7            Ossining Public Library
# 8                    Spring & Waller
# 9                 Spring St, Cofield
# 10                      Wishnie Park
#
#                                               Address  \
# 0   225-207 Albany Post Rd, Briarcliff Manor, NY 1...
# 1                  100 Croton Ave, Ossining, NY 10562
# 2   Croton Ave & Pleasantville Rd, Ossining, NY 10562
# 3                     160 Main St, Ossining, NY 10562
# 4                      1 Secor Rd, Ossining, NY 10562
# 5                 1-15 Leonard St, Ossining, NY 10562
# 6                  20 Madison Ave, Ossining, NY 10562
# 7                   53 Croton Ave, Ossining, NY 10562
# 8          Spring St & Waller Ave, Ossining, NY 10562
# 9           Spring St & Broad Ave, Ossining, NY 10562
# 10     145-149 Orchard Rd, Briarcliff Manor, NY 10510
#
#                   Geolocation  Start Count  End Count
# 0    (41.1394616, -73.861803)          166         40
# 1    (41.1653387, -73.856297)           95         54
# 2   (41.1669377, -73.8497735)           93         50
# 3   (41.1609922, -73.8627212)           50         72
# 4     (41.157844, -73.868112)          150        129
# 5   (41.1618223, -73.8629757)           66        150
# 6   (41.1521048, -73.8623897)          166        257
# 7   (41.1642872, -73.8604165)           51         84
# 8   (41.1593892, -73.8638232)           32         65
# 9   (41.1570899, -73.8640002)           59         91
# 10  (41.1607067, -73.8477673)           86        106

# %%
addresses_df['Total Count'] = addresses_df['Start Count'] + addresses_df['End Count']
addresses_df.sort_values(by='Total Count', ascending=False, inplace=True)
addresses_df
# Out:
#                                  Hub  \
# 6                        Nelson park
# 4                Metro North - Plaza
# 5       Municipal Parking Lot Lot# 7
# 0           Arcadian Shopping Center
# 10                      Wishnie Park
# 9                 Spring St, Cofield
# 1                     C Town Markets
# 2   Cronton Ave & Pleasantville Road
# 7            Ossining Public Library
# 3                      Market Square
# 8                    Spring & Waller
#
#                                               Address  \
# 6                  20 Madison Ave, Ossining, NY 10562
# 4                      1 Secor Rd, Ossining, NY 10562
# 5                 1-15 Leonard St, Ossining, NY 10562
# 0   225-207 Albany Post Rd, Briarcliff Manor, NY 1...
# 10     145-149 Orchard Rd, Briarcliff Manor, NY 10510
# 9           Spring St & Broad Ave, Ossining, NY 10562
# 1                  100 Croton Ave, Ossining, NY 10562
# 2   Croton Ave & Pleasantville Rd, Ossining, NY 10562
# 7                   53 Croton Ave, Ossining, NY 10562
# 3                     160 Main St, Ossining, NY 10562
# 8          Spring St & Waller Ave, Ossining, NY 10562
#
#                   Geolocation  Start Count  End Count  Total Count
# 6   (41.1521048, -73.8623897)          166        257          423
# 4     (41.157844, -73.868112)          150        129          279
# 5   (41.1618223, -73.8629757)           66        150          216
# 0    (41.1394616, -73.861803)          166         40          206
# 10  (41.1607067, -73.8477673)           86        106          192
# 9   (41.1570899, -73.8640002)           59         91          150
# 1    (41.1653387, -73.856297)           95         54          149
# 2   (41.1669377, -73.8497735)           93         50          143
# 7   (41.1642872, -73.8604165)           51         84          135
# 3   (41.1609922, -73.8627212)           50         72          122
# 8   (41.1593892, -73.8638232)           32         65           97

# %%
addresses_df['Single Hub Count'] = addresses_df['Hub'].apply(
    lambda hub: df[(df['Hub Pair'] == f"('{hub}', '{hub}')")]['Total Count'].sum()
)

addresses_df
# Out:
#                                  Hub  \
# 6                        Nelson park
# 4                Metro North - Plaza
# 5       Municipal Parking Lot Lot# 7
# 0           Arcadian Shopping Center
# 10                      Wishnie Park
# 9                 Spring St, Cofield
# 1                     C Town Markets
# 2   Cronton Ave & Pleasantville Road
# 7            Ossining Public Library
# 3                      Market Square
# 8                    Spring & Waller
#
#                                               Address  \
# 6                  20 Madison Ave, Ossining, NY 10562
# 4                      1 Secor Rd, Ossining, NY 10562
# 5                 1-15 Leonard St, Ossining, NY 10562
# 0   225-207 Albany Post Rd, Briarcliff Manor, NY 1...
# 10     145-149 Orchard Rd, Briarcliff Manor, NY 10510
# 9           Spring St & Broad Ave, Ossining, NY 10562
# 1                  100 Croton Ave, Ossining, NY 10562
# 2   Croton Ave & Pleasantville Rd, Ossining, NY 10562
# 7                   53 Croton Ave, Ossining, NY 10562
# 3                     160 Main St, Ossining, NY 10562
# 8          Spring St & Waller Ave, Ossining, NY 10562
#
#                   Geolocation  Start Count  End Count  Total Count  \
# 6   (41.1521048, -73.8623897)          166        257          423
# 4     (41.157844, -73.868112)          150        129          279
# 5   (41.1618223, -73.8629757)           66        150          216
# 0    (41.1394616, -73.861803)          166         40          206
# 10  (41.1607067, -73.8477673)           86        106          192
# 9   (41.1570899, -73.8640002)           59         91          150
# 1    (41.1653387, -73.856297)           95         54          149
# 2   (41.1669377, -73.8497735)           93         50          143
# 7   (41.1642872, -73.8604165)           51         84          135
# 3   (41.1609922, -73.8627212)           50         72          122
# 8   (41.1593892, -73.8638232)           32         65           97
#
#     Single Hub Count
# 6                159
# 4                 78
# 5                 47
# 0                 40
# 10                86
# 9                 59
# 1                 48
# 2                 46
# 7                 45
# 3                 38
# 8                 27

# %% [markdown]
# ## Map
# Create a simple map visualizing each hub pair.

# %% [markdown]
# Calculate the min and max number of trips in the grouped data.

# %%
# min_count = grouped_df['Count'].min()
# max_count = grouped_df['Count'].max()

min_count = df['Total Count'].min()
max_count = df['Total Count'].max()

min_count, max_count
# Out:
# (np.int64(1), np.int64(159))

# %% [markdown]
# Do some mappping.

# %% [markdown]
# Generate a set of colors we can tolerate.

# %%
import seaborn as sns

# Generate a list of colors with a lot of variation between them
num_colors = len(df) * 10
colors = sns.color_palette("tab20", num_colors).as_hex()

colors
# Out:
# ['#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5',
#  '#8c564b',
#  '#c49c94',
#  '#e377c2',
#  '#f7b6d2',
#  '#7f7f7f',
#  '#c7c7c7',
#  '#bcbd22',
#  '#dbdb8d',
#  '#17becf',
#  '#9edae5',
#  '#1f77b4',
#  '#aec7e8',
#  '#ff7f0e',
#  '#ffbb78',
#  '#2ca02c',
#  '#98df8a',
#  '#d62728',
#  '#ff9896',
#  '#9467bd',
#  '#c5b0d5']

# %% [markdown]
# Create the map object.

# %%
import folium

# Create a map centered on Ossining, NY
map = folium.Map(location=[41.162, -73.861], zoom_start=14, tiles='CartoDB dark_matter')

# %% [markdown]
# Add circle markers for each hub

# %%
# Add circles for each unique hub
for _, row in addresses_df.iterrows():
    hub_coords = eval(row['Geolocation'])
    hub_name = row['Hub']
    # Count the number of rows with this location as 'Start Hub Geolocation'
    same_hub_count = round(row['Single Hub Count'] / 2) # divide by 2 since the hub is counted twice if pickup and dropoff are at same hub
    start_hub_count = row['Start Count'] - same_hub_count # exclude trips where pickup/dropoff are at the same hub
    end_hub_count = row['End Count'] - same_hub_count # exclude trips where pickup/dropoff are at the same hub
    total_hub_count = row['Total Count'] - same_hub_count # exclude 1/2 trips counted where pickup/dropoff are at the same hub
    percent_same_hub = round((same_hub_count / total_hub_count) * 100)
    percent_start_hub_count = round((start_hub_count / total_hub_count) * 100)
    percent_end_hub_count = round((end_hub_count / total_hub_count) * 100)
    hub_popup = f'''
    <h4>{hub_name}</h4>
    <p><strong>{total_hub_count}</strong> total trips to/from this hub, including:</p>
    <ul>
        <li><strong>{percent_same_hub}%</strong> ({same_hub_count}) trips both started and ended here</li>
        <li><strong>{percent_start_hub_count}%</strong> ({start_hub_count}) trips started here but ended elsewhere</li>
        <li><strong>{percent_end_hub_count}%</strong> ({end_hub_count}) trips ended here but ended elsewhere</li>
    </ul>
    '''
    folium.CircleMarker(
        location=hub_coords,
        radius= 5 + start_hub_count / 5,  # Base radius is 5, scaled by the count
        color='gray',
        fill=True,
        fill_color='black',
        fill_opacity=0.7,
        popup=folium.Popup(hub_popup, max_width=300, parse_html=False)
    ).add_to(map)

# %% [markdown]
# Iterate through each hub pair and add a line connecting the two.

# %%
# Add lines for each pair of hubs
for _, row in df.iterrows():
    if pd.notnull(row['Hub Pair']):
        start_coords = eval(row['Hub 1 Geolocation'])
        end_coords = eval(row['Hub 2 Geolocation'])
        # start_coords = (start_coords[0] + 0.0005, start_coords[1] + 0.0005) # offset the start coords a bit to separate them from other lines going the other direction
        random_color = np.random.choice(colors) # get a random color from the list
        line_weight = row['Total Count'] / 5  # Adjust the weight based on the count
        line = folium.PolyLine([start_coords, end_coords], color=random_color, weight=line_weight)

        # a popup that shows the number of trips between the two hubs in either direction
        hub1_name = row['Hub Pair'].split(",")[0].strip("(' ")
        hub2_name = row['Hub Pair'].split(",")[1].strip(")' ")
        percent_hub1_start = round((row['Hub 1 Start Count'] / row['Total Count']) * 100)
        percent_hub2_start = round((row['Hub 2 Start Count'] / row['Total Count']) * 100)

        popup_text = f'''
        <h4>{hub1_name} <-> {hub2_name}</h4>
        <p><strong>{row['Total Count']}</strong> total trips between the two, including:</p>
        <ul>
            <li><strong>{percent_hub1_start}%</strong> ({row['Hub 1 Start Count']}): {hub1_name} <strong>--></strong> {hub2_name}</li>
            <li><strong>{percent_hub2_start}%</strong> ({row['Hub 2 Start Count']}): {hub2_name} <strong>--></strong> {hub1_name}</li>
        </ul>
        '''
        folium.Popup(popup_text, max_width=300, parse_html=False).add_to(line) # add to line
        # folium.Popup(popup_text, max_width=300, parse_html=False).add_to(arrow_head) # add to arrow head too

        # add line to map
        line.add_to(map) # add line to map


# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d4097721db7c1d725765e1697d27626 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d4097721db7c1d725765e1697d27626&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d4097721db7c1d725765e1697d27626 = L.map(
#                 &quot;map_8d4097721db7c1d725765e1697d27626&quot;,
#                 {
#                     center: [41.162, -73.861],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a4918f9058cd7c8bc840c8d6a21a0285 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a4918f9058cd7c8bc840c8d6a21a0285.addTo(map_8d4097721db7c1d725765e1697d27626);
#
#
#             var circle_marker_8be387b4e9e4f1d67324616a3d2a5b67 = L.circleMarker(
#                 [41.1521048, -73.8623897],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 22.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8d4097721db7c1d725765e1697d27626);
#
#
#         var popup_3c89be734146404f10b00f8c79c1f065 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_e3596c44f81f807d3ab119fc362583cd = $(`&lt;div id=&quot;html_e3596c44f81f807d3ab119fc362583cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;h4&gt;Nelson park&lt;/h4&gt;     &lt;p&gt;&lt;strong&gt;343&lt;/strong&gt; total trips to/from this hub, including:&lt;/p&gt;     &lt;ul&gt;         &lt;li&gt;&lt;strong&gt;23%&lt;/strong&gt; (80) trips both started and ended here&lt;/li&gt;         &lt;li&gt;&lt;strong&gt;25%&lt;/strong&gt; (86) trips started here but ended elsewhere&lt;/li&gt;         &lt;li&gt;&lt;strong&gt;52%&lt;/strong&gt; (177) trips ended here but ended elsewhere&lt;/li&gt;     &lt;/ul&gt;     &lt;/div&gt;`)[0];
#                 popup_3c89be734146404f10b00f8c79c1f065.setContent(html_e3596c44f81f807d3ab119fc362583cd);
#
#
#
#         circle_marker_8be387b4e9e4f1d67324616a3d2a5b67.bindPopup(popup_3c89be734146404f10b00f8c79c1f065)
#         ;
#
#
#
#
#             var circle_marker_2b0ecfb3235af09fe9e83c40573c35c6 = L.circleMarker(
#                 [41.157844, -73.868112],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 27.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8d4097721db7c1d725765e1697d27626);
#
#
#         var popup_39321006b8ae4da0a1890815178177b2 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_f7e6bf2462c4b731ae417c0f50dee363 = $(`&lt;div id=&quot;html_f7e6bf2462c4b731ae417c0f50dee363&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;h4&gt;Metro North - Plaza&lt;/h4&gt;     &lt;p&gt;&lt;strong&gt;240&lt;/strong&gt; total trips to/from this hub, including:&lt;/p&gt;     &lt;ul&gt;         &lt;li&gt;&lt;strong&gt;16%&lt;/strong&gt; (39) trips both started and ended here&lt;/li&gt;         &lt;li&gt;&lt;strong&gt;46%&lt;/strong&gt; (111) trips started here but ended elsewhere&lt;/li&gt;         &lt;li&gt;&lt;strong&gt;38%&lt;/strong&gt; (90) trips ended here but ended elsewhere&lt;/li&gt;     &lt;/ul&gt;     &lt;/div&gt;`)[0];
#                 popup_39321006b8ae4da0a1890815178177b2.setContent(html_f7e6bf2462c4b731ae417c0f50dee363);
#
#
#
#         circle_marker_2b0ecfb3235af09fe9e83c40573c35c6.bindPopup(popup_39321006b8ae4da0a1890815178177b2)
#         ;
#
#
#
#
#             var circle_marker_cc2167eb8eec675349976ec4b31348c5 = L.circleMarker(
#                 [41.1618223, -73.8629757],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;:

# %%
# Ensure the renders directory exists
renders_dir = Path('./renders').resolve()
renders_dir.mkdir(parents=True, exist_ok=True)

# Save the map to an HTML file in the renders directory
map_file_path = renders_dir / 'all-trips-map.html'
map.save(str(map_file_path))
