# %% [markdown]
# # Step 1: cleanup the raw trip data

# %% [markdown]
# ## import dependencies

# %% [markdown]
# Code dependencies.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Markdown
from geopy.geocoders import Nominatim # max 1 requeset per second
from geopy.exc import GeocoderTimedOut #

# %% [markdown]
# Import the original data file.

# %%
# Load the CSV file into a dataframe
df = pd.read_csv(Path("data/all-trips.csv").resolve())

df.shape
# Out:
# (1458, 7)

# %% [markdown]
# Show a random sample of the data.

# %%
df.sample(10)
# Out:
#         plate                 Start Hub                           End Hub  \
# 966   9140012             Market Square          Arcadian Shopping Center
# 772   9140015   Ossining Public Library  Cronton Ave & Pleasantville Road
# 283   9140045   Ossining Public Library           Ossining Public Library
# 801   9140038              Wishnie Park  Cronton Ave & Pleasantville Road
# 816   9140031  Arcadian Shopping Center          Arcadian Shopping Center
# 785   9140007  Arcadian Shopping Center                      Wishnie Park
# 890   9140008             Market Square  Cronton Ave & Pleasantville Road
# 1245  9140009             Market Square                     Market Square
# 586   9140003        Spring St, Cofield                Spring St, Cofield
# 1043  9140034            C Town Markets                    C Town Markets
#
#             Date           Start Time Trip Durration  Billing Zip Code
# 966   2024-09-09  2024-09-09 13:46:00        1:07:12           10565.0
# 772   2024-09-19  2024-09-19 14:39:01        0:04:38           10562.0
# 283   2024-10-19  2024-10-19 16:17:55        4:54:16           10562.0
# 801   2024-10-04  2024-10-04 23:40:19        1:02:09           10562.0
# 816   2024-10-07  2024-10-07 21:53:25        0:22:10           10562.0
# 785   2024-10-13  2024-10-13 14:37:03        1:06:01           10562.0
# 890   2024-09-09  2024-09-09 14:51:52        0:01:32           10562.0
# 1245  2024-08-30  2024-08-30 11:38:52        0:39:26           10562.0
# 586   2024-09-12   2024-09-12 6:43:13        0:09:29           10562.0
# 1043  2024-09-20  2024-09-20 22:37:42        0:38:59           10562.0

# %% [markdown]
# ## Hub names
# Establish a set of the hub names in the data.

# %%
# Combine unique values from 'Start Hub' and 'End Hub' columns
unique_starts = df['Start Hub'].dropna().unique() # unique start hubs
unique_ends = df['End Hub'].dropna().unique() # unique end hubs
unique_hubs_combined = np.concatenate((unique_starts, unique_ends)) # combine the two arrays
unique_hubs_combined = np.unique(unique_hubs_combined) # remove duplicates

# Convert to a list
unique_hubs_list = unique_hubs_combined

unique_hubs_list
# Out:
# array(['Arcadian Shopping Center', 'C Town Markets',
#        'Cronton Ave & Pleasantville Road', 'Market Square',
#        'Metro North - Plaza', 'Municipal Parking Lot Lot# 7',
#        'Nelson park', 'Ossining Public Library', 'Spring & Waller',
#        'Spring St, Cofield', 'Wishnie Park'], dtype=object)

# %% [markdown]
# ## Hub addresses
# Hard-code approximate addresses for each hub so we can geolocate them.

# %%
# addresses of each hub
addresses = {
'Arcadian Shopping Center': "225-207 Albany Post Rd, Briarcliff Manor, NY 10510", 
'C Town Markets': "100 Croton Ave, Ossining, NY 10562",
'Cronton Ave & Pleasantville Road': "Croton Ave & Pleasantville Rd, Ossining, NY 10562", 
'Market Square': "160 Main St, Ossining, NY 10562",
'Metro North - Plaza': "1 Secor Rd, Ossining, NY 10562", 
'Municipal Parking Lot Lot# 7': "1-15 Leonard St, Ossining, NY 10562",
'Nelson park': "20 Madison Ave, Ossining, NY 10562", 
'Ossining Public Library': "53 Croton Ave, Ossining, NY 10562", 
'Spring & Waller': "Spring St & Waller Ave, Ossining, NY 10562",
'Spring St, Cofield': "Spring St & Broad Ave, Ossining, NY 10562", 
'Wishnie Park': "145-149 Orchard Rd, Briarcliff Manor, NY 10510"
}

# %%
# Create a dataframe from the addresses dictionary
addresses_df = pd.DataFrame(list(addresses.items()), columns=['Hub', 'Address'])

addresses_df
# Out:
#                                  Hub  \
# 0           Arcadian Shopping Center
# 1                     C Town Markets
# 2   Cronton Ave & Pleasantville Road
# 3                      Market Square
# 4                Metro North - Plaza
# 5       Municipal Parking Lot Lot# 7
# 6                        Nelson park
# 7            Ossining Public Library
# 8                    Spring & Waller
# 9                 Spring St, Cofield
# 10                      Wishnie Park
#
#                                               Address
# 0   225-207 Albany Post Rd, Briarcliff Manor, NY 1...
# 1                  100 Croton Ave, Ossining, NY 10562
# 2   Croton Ave & Pleasantville Rd, Ossining, NY 10562
# 3                     160 Main St, Ossining, NY 10562
# 4                      1 Secor Rd, Ossining, NY 10562
# 5                 1-15 Leonard St, Ossining, NY 10562
# 6                  20 Madison Ave, Ossining, NY 10562
# 7                   53 Croton Ave, Ossining, NY 10562
# 8          Spring St & Waller Ave, Ossining, NY 10562
# 9           Spring St & Broad Ave, Ossining, NY 10562
# 10     145-149 Orchard Rd, Briarcliff Manor, NY 10510

# %% [markdown]
# ## Geocode
# Use the `geopy` library to geocode hub addresses.

# %%
# Initialize geocoder using OpenStreetMap's Nominatim... throttles requests to 1 per second max
geolocator = Nominatim(user_agent="bike-ped")
#geolocator = RateLimiter(nom.geocode, min_delay_seconds=1) # throttle to not anger the APIgods

# Function to geocode addresses
def geocode_address(address):
    try:
        location = geolocator.geocode(address, exactly_one=True, extratags=True, timeout=10)
        if location:
            print(location.raw)
            return location.latitude, location.longitude, location.raw
    except GeocoderTimedOut:
        pass
    return np.nan, np.nan

# %% [markdown]
# Geocode each hub address.... this crashes at the end, but otherwise works.

# %%
# Geocode all addresses
addresses_df['OpenStreetMap Data'] = addresses_df['Address'].apply(geocode_address)
# Out:
# {'place_id': 328948482, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 260854757, 'lat': '41.1394616', 'lon': '-73.8618030', 'class': 'highway', 'type': 'primary', 'place_rank': 26, 'importance': 0.05338392538338289, 'addresstype': 'road', 'name': 'South Highland Avenue', 'display_name': 'South Highland Avenue, Scarborough, Village of Briarcliff Manor, Town of Ossining, Westchester County, New York, 10510, United States', 'extratags': {'lanes': '3', 'surface': 'asphalt', 'maxspeed': '40 mph', 'sidewalk': 'no', 'lanes:forward': '1', 'lanes:backward': '1', 'lanes:both_ways': '1', 'turn:lanes:both_ways': 'left'}, 'boundingbox': ['41.1379390', '41.1411018', '-73.8618067', '-73.8612486']}
# {'place_id': 330584028, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 745301090, 'lat': '41.1653387', 'lon': '-73.8562970', 'class': 'building', 'type': 'retail', 'place_rank': 30, 'importance': 5.401922636754433e-05, 'addresstype': 'building', 'name': '', 'display_name': '100, Croton Avenue, Village of Ossining, Town of Ossining, Westchester County, New York, 10562, United States', 'extratags': {'nysgissam:nysaddresspointid': 'WEST080881'}, 'boundingbox': ['41.1650649', '41.1655496', '-73.8566824', '-73.8559047']}
# {'place_id': 328586537, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 6796208044, 'lat': '41.1669377', 'lon': '-73.8497735', 'class': 'highway', 'type': 'bus_stop', 'place_rank': 30, 'importance': 5.401922636754433e-05, 'addresstype': 'highway', 'name': 'CROTON AVE @ PLEASANTVILLE RD', 'display_name': 'CROTON AVE @ PLEASANTVILLE RD, Croton Avenue, Village of Ossining, Town of Ossining, Westchester County, New York, 10562, United States', 'extratags': {'bus': 'yes', 'network': 'Bee-Line Bus', 'operator': 'Westchester County Department of Public Works and Transportation', 'departures_board': 'timetable', 'public_transport': 'platform'}, 'boundingbox': ['41.1668877', '41.1669877', '-73.8498235', '-73.8497235']}
# {'place_id': 327813404, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 744555438, 'lat': '41.1609922', 'lon': '-73.8627212', 'class': 'building', 'type': 'yes', 'place_rank': 30, 'importance': 5.401922636754433e-05, 'addresstype': 'building', 'name': '', 'display_name': '160, Main Street, Village of Ossining, Town of Ossining, Westchester County, New York, 10562, United States', 'extratags': {'nysgissam:nysaddresspointid': 'WEST081695'}, 'boundingbox': ['41.1607832', '41.1611496', '-73.8627939', '-73.8626276']}
# {'place_id': 365405434, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 23476866, 'lat': '41.1578440', 'lon': '-73.8681120', 'class': 'place', 'type': 'house', 'place_rank': 30, 'importance': 9.99999999995449e-06, 'addresstype': 'place', 'name': '', 'display_name': '1, Secor Road, Village of Ossining, Town of Ossining, Westchester County, New York, 10562, United States', 'extratags': None, 'boundingbox': ['41.1577940', '41.1578940', '-73.8681620', '-73.8680620']}
# {'place_id': 335465341, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 23476308, 'lat': '41.1618223', 'lon': '-73.8629757', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.05338735255970089, 'addresstype': 'road', 'name': 'Leonard Street', 'display_name': 'Leonard Street, Village of Ossining, Town of Ossining, Westchester County, New York, 10562, United States', 'extratags': None, 'boundingbox': ['41.1617202', '41.1622040', '-73.8635170', '-73.8627852']}
# {'place_id': 329884689, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 8805963631, 'lat': '41.1521048', 'lon': '-73.8623897', 'class': 'place', 'type': 'house', 'place_rank': 30, 'importance': 5.401922636754433e-05, 'addresstype': 'place', 'name': '', 'display_name': '20, Madison Avenue, Village of Ossining, Town of Ossining, Westchester County, New York, 10562, United States', 'extratags': {'nysgissam:nysaddresspointid': 'WEST082295'}, 'boundingbox': ['41.1520548', '41.1521548', '-73.8624397', '-73.8623397']}
# {'place_id': 330117371, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 745288373, 'lat': '41.1642872', 'lon': '-73.8604165', 'class': 'building', 'type': 'yes', 'place_rank': 30, 'importance': 5.401922636754433e-05, 'addresstype': 'building', 'name': '', 'display_name': '53, Croton Avenue, Village of Ossining, Town of Ossining, Westchester County, New York, 10562, United States', 'extratags': {'nysgissam:nysaddresspointid': 'WEST080712'}, 'boundingbox': ['41.1641066', '41.1644244', '-73.8606477', '-73.8601126']}
# {'place_id': 330188213, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 6796000986, 'lat': '41.1593892', 'lon': '-73.8638232', 'class': 'highway', 'type': 'bus_stop', 'place_rank': 30, 'importance': 5.401922636754433e-05, 'addresstype': 'highway', 'name': 'SPRING ST @ WALLER AVE', 'display_name': 'SPRING ST @ WALLER AVE, Spring Street, Village of Ossining, Town of Ossining, Westchester County, New York, 10562, United States', 'extratags': {'bin': 'yes', 'bus': 'yes', 'bench': 'yes', 'network': 'Bee-Line Bus', 'shelter': 'yes', 'operator': 'Westchester County Department of Public Works and Transportation', 'tactile_paving': 'no', 'departures_board': 'timetable', 'public_transport': 'platform'}, 'boundingbox': ['41.1593392', '41.1594392', '-73.8638732', '-73.8637732']}
# {'place_id': 330122176, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 6796000985, 'lat': '41.1570899', 'lon': '-73.8640002', 'class': 'highway', 'type': 'bus_stop', 'place_rank': 30, 'importance': 5.401922636754433e-05, 'addresstype': 'highway', 'name': 'SPRING ST @ BROAD AVE', 'display_name': 'SPRING ST @ BROAD AVE, Spring Street, Village of Ossining, Town of Ossining, Westchester County, New York, 10562, United States', 'extratags': {'bin': 'no', 'bus': 'yes', 'lit': 'yes', 'bench': 'no', 'network': 'Bee-Line', 'shelter': 'no', 'operator': 'Westchester County Department of Public Works and Transportation', 'operator:short': 'WCDOT', 'tactile_paving': 'yes', 'departures_board': 'timetable', 'network:wikidata': 'Q4879491', 'public_transport': 'platform'}, 'boundingbox': ['41.1570399', '41.1571399', '-73.8640502', '-73.8639502']}
# {'place_id': 327043595, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 23530399, 'lat': '41.1607067', 'lon': '-73.8477673', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.05338392538338289, 'addresstype': 'road', 'name': 'Orchard Road', 'display_name': 'Orchard Road, Village of Briarcliff Manor, Town of Ossining, Westchester County, New York, 10562, United States', 'extratags': {'surface': 'asphalt', 'lane_markings': 'no'}, 'boundingbox': ['41.1578580', '41.1628472', '-73.8489310', '-73.8453889']}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 3
#       1 # Geocode all addresses
#       2 addresses_df['Coordinates'] = addresses_df['Address'].apply(geocode_address)
# ----> 3 addresses_df[['Latitude', 'Longitude']] = pd.DataFrame(addresses_df['Coordinates'].tolist(), index=addresses_df.index)
#
# File ~/.local/share/virtualenvs/project-mover-4KfBeeR9/lib/python3.12/site-packages/pandas/core/frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4297     self._setitem_frame(key, value)
#    4298 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299     self._setitem_array(key, value)
#    4300 elif isinstance(value, DataFrame):
#    4301     self._set_item_frame_value(key, value)
#
# File ~/.local/share/virtualenvs/project-mover-4KfBeeR9/lib/python3.12/site-packages/pandas/core/frame.py:4341, in DataFrame._setitem_array(self, key, value)
#    4336 else:
#    4337     # Note: unlike self.iloc[:, indexer] = value, this will
#    4338     #  never try to overwrite values inplace
#    4340     if isinstance(value, DataFrame):
# -> 4341         check_key_length(self.columns, key, value)
#    4342         for k1, k2 in zip(key, value.columns):
#    4343             self[k1] = value[k2]
#
# File ~/.local/share/virtualenvs/project-mover-4KfBeeR9/lib/python3.12/site-packages/pandas/core/indexers/utils.py:390, in check_key_length(columns, key, value)
#     388 if columns.is_unique:
#     389     if len(value.columns) != len(key):
# --> 390         raise ValueError("Columns must be same length as key")
#     391 else:
#     392     # Missing keys in columns are represented as -1
#     393     if len(columns.get_indexer_non_unique(key)[0]) != len(value.columns):
#
# ValueError: Columns must be same length as key

# %%
addresses_df
# Out:
#                                  Hub  \
# 0           Arcadian Shopping Center
# 1                     C Town Markets
# 2   Cronton Ave & Pleasantville Road
# 3                      Market Square
# 4                Metro North - Plaza
# 5       Municipal Parking Lot Lot# 7
# 6                        Nelson park
# 7            Ossining Public Library
# 8                    Spring & Waller
# 9                 Spring St, Cofield
# 10                      Wishnie Park
#
#                                               Address  \
# 0   225-207 Albany Post Rd, Briarcliff Manor, NY 1...
# 1                  100 Croton Ave, Ossining, NY 10562
# 2   Croton Ave & Pleasantville Rd, Ossining, NY 10562
# 3                     160 Main St, Ossining, NY 10562
# 4                      1 Secor Rd, Ossining, NY 10562
# 5                 1-15 Leonard St, Ossining, NY 10562
# 6                  20 Madison Ave, Ossining, NY 10562
# 7                   53 Croton Ave, Ossining, NY 10562
# 8          Spring St & Waller Ave, Ossining, NY 10562
# 9           Spring St & Broad Ave, Ossining, NY 10562
# 10     145-149 Orchard Rd, Briarcliff Manor, NY 10510
#
#                                           Coordinates
# 0   (41.1394616, -73.861803, {'place_id': 32894848...
# 1   (41.1653387, -73.856297, {'place_id': 33058402...
# 2   (41.1669377, -73.8497735, {'place_id': 3285865...
# 3   (41.1609922, -73.8627212, {'place_id': 3278134...
# 4   (41.157844, -73.868112, {'place_id': 365405434...
# 5   (41.1618223, -73.8629757, {'place_id': 3354653...
# 6   (41.1521048, -73.8623897, {'place_id': 3298846...
# 7   (41.1642872, -73.8604165, {'place_id': 3301173...
# 8   (41.1593892, -73.8638232, {'place_id': 3301882...
# 9   (41.1570899, -73.8640002, {'place_id': 3301221...
# 10  (41.1607067, -73.8477673, {'place_id': 3270435...

# %% [markdown]
# Extract just the latitude and longitude from the OpenStreetMap data.

# %%
# Create a 'Geolocation' field with latitude and longitude in parentheses
addresses_df['Geolocation'] = addresses_df['OpenStreetMap Data'].apply(lambda coord: f"({coord[0]}, {coord[1]})")
addresses_df
# Out:
#                                  Hub  \
# 0           Arcadian Shopping Center
# 1                     C Town Markets
# 2   Cronton Ave & Pleasantville Road
# 3                      Market Square
# 4                Metro North - Plaza
# 5       Municipal Parking Lot Lot# 7
# 6                        Nelson park
# 7            Ossining Public Library
# 8                    Spring & Waller
# 9                 Spring St, Cofield
# 10                      Wishnie Park
#
#                                               Address  \
# 0   225-207 Albany Post Rd, Briarcliff Manor, NY 1...
# 1                  100 Croton Ave, Ossining, NY 10562
# 2   Croton Ave & Pleasantville Rd, Ossining, NY 10562
# 3                     160 Main St, Ossining, NY 10562
# 4                      1 Secor Rd, Ossining, NY 10562
# 5                 1-15 Leonard St, Ossining, NY 10562
# 6                  20 Madison Ave, Ossining, NY 10562
# 7                   53 Croton Ave, Ossining, NY 10562
# 8          Spring St & Waller Ave, Ossining, NY 10562
# 9           Spring St & Broad Ave, Ossining, NY 10562
# 10     145-149 Orchard Rd, Briarcliff Manor, NY 10510
#
#                                           Coordinates  \
# 0   (41.1394616, -73.861803, {'place_id': 32894848...
# 1   (41.1653387, -73.856297, {'place_id': 33058402...
# 2   (41.1669377, -73.8497735, {'place_id': 3285865...
# 3   (41.1609922, -73.8627212, {'place_id': 3278134...
# 4   (41.157844, -73.868112, {'place_id': 365405434...
# 5   (41.1618223, -73.8629757, {'place_id': 3354653...
# 6   (41.1521048, -73.8623897, {'place_id': 3298846...
# 7   (41.1642872, -73.8604165, {'place_id': 3301173...
# 8   (41.1593892, -73.8638232, {'place_id': 3301882...
# 9   (41.1570899, -73.8640002, {'place_id': 3301221...
# 10  (41.1607067, -73.8477673, {'place_id': 3270435...
#
#                   Geolocation
# 0    (41.1394616, -73.861803)
# 1    (41.1653387, -73.856297)
# 2   (41.1669377, -73.8497735)
# 3   (41.1609922, -73.8627212)
# 4     (41.157844, -73.868112)
# 5   (41.1618223, -73.8629757)
# 6   (41.1521048, -73.8623897)
# 7   (41.1642872, -73.8604165)
# 8   (41.1593892, -73.8638232)
# 9   (41.1570899, -73.8640002)
# 10  (41.1607067, -73.8477673)

# %% [markdown]
# ## Save geolocations
# Save each hub's address and geolocation to a `hub-locations.csv` file for later use.

# %%
# Save to file
file_path = './data/hub-locations.csv'
file_path = Path(file_path).resolve() # make platform-agnostic
addresses_df.to_csv(file_path, index=False)
