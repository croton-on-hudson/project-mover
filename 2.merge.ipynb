# %% [markdown]
# # Step 2: merge trip and address data

# %% [markdown]
# ## Import dependencies

# %% [markdown]
# Code dependencies.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Markdown

# %% [markdown]
# Import the trip data file.

# %%
# Load the trip data file
df = pd.read_csv(Path("data/all-trips.csv").resolve())

df.sample(5)
# Out:
#         plate                 Start Hub                   End Hub        Date  \
# 373   9140023               Nelson park            C Town Markets  2024-10-13
# 1120  9140022           Spring & Waller   Ossining Public Library  2024-09-05
# 1150  9140014  Arcadian Shopping Center             Market Square  2024-09-20
# 1308  9140012              Wishnie Park              Wishnie Park  2024-08-28
# 709   9140012  Arcadian Shopping Center  Arcadian Shopping Center  2024-10-21
#
#                Start Time Trip Durration  Billing Zip Code
# 373   2024-10-13 20:09:21        0:14:14           10562.0
# 1120  2024-09-05 20:08:03        0:39:48           10601.0
# 1150  2024-09-20 18:14:18        0:13:18           10562.0
# 1308  2024-08-28 11:20:56        0:28:35           12010.0
# 709    2024-10-21 9:50:26        2:42:23           10562.0

# %% [markdown]
# Import the hub locations file.

# %%
addresses_df = pd.read_csv(Path("data/hub-locations.csv").resolve())
addresses_df = addresses_df.drop(columns=["OpenStreetMap Data"]) # drop the column with OSM data... we don't need it here.

addresses_df.sample(5)
# Out:
#                                 Hub  \
# 7           Ossining Public Library
# 1                    C Town Markets
# 6                       Nelson park
# 9                Spring St, Cofield
# 2  Cronton Ave & Pleasantville Road
#
#                                              Address  \
# 7                  53 Croton Ave, Ossining, NY 10562
# 1                 100 Croton Ave, Ossining, NY 10562
# 6                 20 Madison Ave, Ossining, NY 10562
# 9          Spring St & Broad Ave, Ossining, NY 10562
# 2  Croton Ave & Pleasantville Rd, Ossining, NY 10562
#
#                  Geolocation
# 7  (41.1642872, -73.8604165)
# 1   (41.1653387, -73.856297)
# 6  (41.1521048, -73.8623897)
# 9  (41.1570899, -73.8640002)
# 2  (41.1669377, -73.8497735)

# %% [markdown]
# ## Merge data
# Merge the trip data with the hub locations data to get a single data file with everything we need.

# %% [markdown]
# First, merge the Start Hub location.

# %%
# Merge df with addresses_df to add 'Start Hub Geolocation'
df = df.merge(addresses_df[['Hub', 'Geolocation']], left_on='Start Hub', right_on='Hub', how='left')
df = df.rename(columns={'Geolocation': 'Start Hub Geolocation'}).drop(columns=['Hub'])

df.sample(5)
# Out:
#         plate                     Start Hub                           End Hub  \
# 911   9140030      Arcadian Shopping Center                       Nelson park
# 224   9140011                 Market Square                     Market Square
# 1283  9140016  Municipal Parking Lot Lot# 7      Municipal Parking Lot Lot# 7
# 45    9140035           Metro North - Plaza                       Nelson park
# 801   9140038                  Wishnie Park  Cronton Ave & Pleasantville Road
#
#             Date           Start Time Trip Durration  Billing Zip Code  \
# 911   2024-09-13  2024-09-13 16:20:44        0:11:30           10562.0
# 224   2024-11-03  2024-11-03 10:23:50        0:29:20           11230.0
# 1283  2024-09-08  2024-09-08 14:16:00        1:26:29           10520.0
# 45    2024-12-02  2024-12-02 20:00:04        0:06:27           10562.0
# 801   2024-10-04  2024-10-04 23:40:19        1:02:09           10562.0
#
#           Start Hub Geolocation
# 911    (41.1394616, -73.861803)
# 224   (41.1609922, -73.8627212)
# 1283  (41.1618223, -73.8629757)
# 45      (41.157844, -73.868112)
# 801   (41.1607067, -73.8477673)

# %% [markdown]
# Second, merge the End Hub location.

# %%
# Merge df with addresses_df to add 'End Hub Geolocation'
df = df.merge(addresses_df[['Hub', 'Geolocation']], left_on='End Hub', right_on='Hub', how='left')
df = df.rename(columns={'Geolocation': 'End Hub Geolocation'}).drop(columns=['Hub'])

df.sample(5)
# Out:
#         plate                 Start Hub                           End Hub  \
# 752   9140005               Nelson park      Municipal Parking Lot Lot# 7
# 1212  9140004       Metro North - Plaza                       Nelson park
# 67    9140034   Ossining Public Library                       Nelson park
# 811   9140047  Arcadian Shopping Center      Municipal Parking Lot Lot# 7
# 841   9140027       Metro North - Plaza  Cronton Ave & Pleasantville Road
#
#             Date           Start Time Trip Durration  Billing Zip Code  \
# 752   2024-09-17  2024-09-17 11:55:08        0:09:14           10562.0
# 1212  2024-09-02  2024-09-02 13:39:29        0:14:25           10562.0
# 67    2024-11-29  2024-11-29 14:27:54        0:25:45           10562.0
# 811   2024-10-09  2024-10-09 16:19:58        0:11:04           10562.0
# 841   2024-09-27  2024-09-27 23:59:39        0:15:11           10562.0
#
#           Start Hub Geolocation        End Hub Geolocation
# 752   (41.1521048, -73.8623897)  (41.1618223, -73.8629757)
# 1212    (41.157844, -73.868112)  (41.1521048, -73.8623897)
# 67    (41.1642872, -73.8604165)  (41.1521048, -73.8623897)
# 811    (41.1394616, -73.861803)  (41.1618223, -73.8629757)
# 841     (41.157844, -73.868112)  (41.1669377, -73.8497735)

# %% [markdown]
# ## Save
# Save the merged trip and geolocation data to a new CSV file.

# %%
# Save to file
file_path = './data/all-trips-geo.csv'
file_path = Path(file_path).resolve() # make platform-agnostic
df.to_csv(file_path, index=False)

# %% [markdown]
# ## Quick map
# Put together a quick map to visualze all the trip data.

# %% [markdown]
# Count how many trips start and end at each hub combination.

# %%
# Group by 'Start Hub Geolocation' and 'End Hub Geolocation' and count occurrences
grouped_df = df.groupby(['Start Hub Geolocation', 'End Hub Geolocation']).size().reset_index(name='Count')

grouped_df.head(30)
# Out:
#         Start Hub Geolocation        End Hub Geolocation  Count
# 0    (41.1394616, -73.861803)   (41.1394616, -73.861803)     40
# 1    (41.1394616, -73.861803)  (41.1521048, -73.8623897)      8
# 2    (41.1394616, -73.861803)  (41.1570899, -73.8640002)      4
# 3    (41.1394616, -73.861803)    (41.157844, -73.868112)      8
# 4    (41.1394616, -73.861803)  (41.1593892, -73.8638232)     16
# 5    (41.1394616, -73.861803)  (41.1607067, -73.8477673)      6
# 6    (41.1394616, -73.861803)  (41.1609922, -73.8627212)     14
# 7    (41.1394616, -73.861803)  (41.1618223, -73.8629757)     46
# 8    (41.1394616, -73.861803)  (41.1642872, -73.8604165)      9
# 9    (41.1394616, -73.861803)   (41.1653387, -73.856297)      9
# 10   (41.1394616, -73.861803)  (41.1669377, -73.8497735)      6
# 11  (41.1521048, -73.8623897)   (41.1394616, -73.861803)     22
# 12  (41.1521048, -73.8623897)  (41.1521048, -73.8623897)    159
# 13  (41.1521048, -73.8623897)  (41.1570899, -73.8640002)      1
# 14  (41.1521048, -73.8623897)    (41.157844, -73.868112)     58
# 15  (41.1521048, -73.8623897)  (41.1593892, -73.8638232)      4
# 16  (41.1521048, -73.8623897)  (41.1609922, -73.8627212)      3
# 17  (41.1521048, -73.8623897)  (41.1618223, -73.8629757)      4
# 18  (41.1521048, -73.8623897)  (41.1642872, -73.8604165)      2
# 19  (41.1521048, -73.8623897)   (41.1653387, -73.856297)      9
# 20  (41.1521048, -73.8623897)  (41.1669377, -73.8497735)      2
# 21  (41.1570899, -73.8640002)   (41.1394616, -73.861803)     14
# 22  (41.1570899, -73.8640002)  (41.1521048, -73.8623897)      3
# 23  (41.1570899, -73.8640002)  (41.1570899, -73.8640002)     59
# 24  (41.1570899, -73.8640002)    (41.157844, -73.868112)      6
# 25  (41.1570899, -73.8640002)  (41.1593892, -73.8638232)      1
# 26  (41.1570899, -73.8640002)  (41.1609922, -73.8627212)      1
# 27  (41.1570899, -73.8640002)  (41.1618223, -73.8629757)      1
# 28  (41.1570899, -73.8640002)  (41.1642872, -73.8604165)      1
# 29  (41.1570899, -73.8640002)   (41.1653387, -73.856297)      4

# %% [markdown]
# Calculate the min and max number of trips in the grouped data.

# %%
min_count = grouped_df['Count'].min()
max_count = grouped_df['Count'].max()

min_count, max_count
# Out:
# (np.int64(1), np.int64(159))

# %%
import folium

# Create a map centered on Ossining, NY
map = folium.Map(location=[41.162, -73.861], zoom_start=14)


# Add lines for each trip
for _, row in grouped_df.iterrows():
    if pd.notnull(row['Start Hub Geolocation']) and pd.notnull(row['End Hub Geolocation']):
        start_coords = eval(row['Start Hub Geolocation'])
        end_coords = eval(row['End Hub Geolocation'])
        random_color = np.random.choice(['red', 'blue', 'green', 'purple', 'orange', 'yellow'])
        line_weight = row['Count'] / 10  # Adjust the weight based on the count
        line = folium.PolyLine([start_coords, end_coords], color=random_color, weight=line_weight)
        # Add a popup to display the count of trips
        popup_text = f"Trips: {row['Count']}"
        folium.Popup(popup_text).add_to(line)
        # add line to map
        line.add_to(map)


        # Add start and end geolocations as black circles
        folium.CircleMarker(
            location=start_coords,
            radius=row['Count'] / 10,  # Adjust the radius based on the count
            color='black',
            fill=True,
            fill_color='black'
        ).add_to(map)
        folium.CircleMarker(
            location=end_coords,
            radius=row['Count'] / 10,  # Adjust the radius based on the count
            color='black',
            fill=True,
            fill_color='black'
        ).add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26c1ca9506adcb632f4374e6346b7eca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26c1ca9506adcb632f4374e6346b7eca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_26c1ca9506adcb632f4374e6346b7eca = L.map(
#                 &quot;map_26c1ca9506adcb632f4374e6346b7eca&quot;,
#                 {
#                     center: [41.162, -73.861],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_71f8b35d7a31b065e7817b75343f6972 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_71f8b35d7a31b065e7817b75343f6972.addTo(map_26c1ca9506adcb632f4374e6346b7eca);
#
#
#             var poly_line_3441d6aaec6ce38480a811506c7d0fdc = L.polyline(
#                 [[41.1394616, -73.861803], [41.1394616, -73.861803]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 4.0}
#             ).addTo(map_26c1ca9506adcb632f4374e6346b7eca);
#
#
#             var circle_marker_e9d2c927f21c60dbd076dcde131f9800 = L.circleMarker(
#                 [41.1394616, -73.861803],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_26c1ca9506adcb632f4374e6346b7eca);
#
#
#             var circle_marker_b06d4bade5d6a50afdfd377237815a1d = L.circleMarker(
#                 [41.1394616, -73.861803],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_26c1ca9506adcb632f4374e6346b7eca);
#
#
#             var poly_line_8834a4e17bf232c2a74b958af895b9f7 = L.polyline(
#                 [[41.1394616, -73.861803], [41.1521048, -73.8623897]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 0.8}
#             ).addTo(map_26c1ca9506adcb632f4374e6346b7eca);
#
#
#             var circle_marker_07325cda5e16e3ad70dd9f35b3b116a4 = L.circleMarker(
#                 [41.1394616, -73.861803],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_26c1ca9506adcb632f4374e6346b7eca);
#
#
#             var circle_marker_fc562d4559f81bad9ff2579f52f33191 = L.circleMarker(
#                 [41.1521048, -73.8623897],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_26c1ca9506adcb632f4374e6346b7eca);

# %%
# Ensure the renders directory exists
renders_dir = Path('./renders').resolve()
renders_dir.mkdir(parents=True, exist_ok=True)

# Save the map to an HTML file in the renders directory
map_file_path = renders_dir / 'all-trips-map.html'
map.save(str(map_file_path))
