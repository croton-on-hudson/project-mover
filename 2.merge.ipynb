# %% [markdown]
# # Step 2: merge trip and address data

# %% [markdown]
# ## Import dependencies

# %% [markdown]
# Code dependencies.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Markdown

# %% [markdown]
# Import the trip data file.

# %%
# Load the trip data file
df = pd.read_csv(Path("data/all-trips.csv").resolve())

df.sample(5)
# Out:
#         plate                         Start Hub  \
# 876   9140040  Cronton Ave & Pleasantville Road
# 1093  9140036                     Market Square
# 801   9140038                      Wishnie Park
# 1002  9140034                       Nelson park
# 855   9140039      Municipal Parking Lot Lot# 7
#
#                                End Hub        Date           Start Time  \
# 876   Cronton Ave & Pleasantville Road  2024-09-20   2024-09-20 9:28:28
# 1093               Metro North - Plaza  2024-09-07  2024-09-07 12:11:14
# 801   Cronton Ave & Pleasantville Road  2024-10-04  2024-10-04 23:40:19
# 1002               Metro North - Plaza  2024-09-13  2024-09-13 18:32:56
# 855           Arcadian Shopping Center  2024-10-11  2024-10-11 15:38:01
#
#      Trip Durration  Billing Zip Code
# 876         0:35:51           10562.0
# 1093        1:25:31           10927.0
# 801         1:02:09           10562.0
# 1002        1:18:17           10562.0
# 855         0:14:41           10562.0

# %% [markdown]
# Import the hub locations file.

# %%
addresses_df = pd.read_csv(Path("data/hub-locations.csv").resolve())
addresses_df = addresses_df.drop(columns=["OpenStreetMap Data"]) # drop the column with OSM data... we don't need it here.

addresses_df.sample(5)
# Out:
#                          Hub  \
# 1             C Town Markets
# 9         Spring St, Cofield
# 0   Arcadian Shopping Center
# 10              Wishnie Park
# 7    Ossining Public Library
#
#                                               Address  \
# 1                  100 Croton Ave, Ossining, NY 10562
# 9           Spring St & Broad Ave, Ossining, NY 10562
# 0   225-207 Albany Post Rd, Briarcliff Manor, NY 1...
# 10     145-149 Orchard Rd, Briarcliff Manor, NY 10510
# 7                   53 Croton Ave, Ossining, NY 10562
#
#                   Geolocation
# 1    (41.1653387, -73.856297)
# 9   (41.1570899, -73.8640002)
# 0    (41.1394616, -73.861803)
# 10  (41.1607067, -73.8477673)
# 7   (41.1642872, -73.8604165)

# %% [markdown]
# ## Merge data
# Merge the trip data with the hub locations data to get a single data file with everything we need.

# %% [markdown]
# First, merge the Start Hub location.

# %%
# Merge df with addresses_df to add 'Start Hub Geolocation'
df = df.merge(addresses_df[['Hub', 'Geolocation']], left_on='Start Hub', right_on='Hub', how='left')
df = df.rename(columns={'Geolocation': 'Start Hub Geolocation'}).drop(columns=['Hub'])

df.sample(5)
# Out:
#        plate                         Start Hub  \
# 990  9140018  Cronton Ave & Pleasantville Road
# 332  9140037                     Market Square
# 627  9140002          Arcadian Shopping Center
# 600  9140045           Ossining Public Library
# 906  9140025           Ossining Public Library
#
#                               End Hub        Date           Start Time  \
# 990               Metro North - Plaza  2024-09-14  2024-09-14 17:28:22
# 332          Arcadian Shopping Center  2024-10-18  2024-10-18 14:54:47
# 627      Municipal Parking Lot Lot# 7  2024-10-28  2024-10-28 19:30:13
# 600           Ossining Public Library  2024-09-27  2024-09-27 20:35:58
# 906  Cronton Ave & Pleasantville Road  2024-09-12   2024-09-12 9:16:09
#
#     Trip Durration  Billing Zip Code      Start Hub Geolocation
# 990        0:28:15           10562.0  (41.1669377, -73.8497735)
# 332        0:08:29           10562.0  (41.1609922, -73.8627212)
# 627        0:10:10           10562.0   (41.1394616, -73.861803)
# 600        2:20:31           10562.0  (41.1642872, -73.8604165)
# 906        0:06:57           10562.0  (41.1642872, -73.8604165)

# %% [markdown]
# Second, merge the End Hub location.

# %%
# Merge df with addresses_df to add 'End Hub Geolocation'
df = df.merge(addresses_df[['Hub', 'Geolocation']], left_on='End Hub', right_on='Hub', how='left')
df = df.rename(columns={'Geolocation': 'End Hub Geolocation'}).drop(columns=['Hub'])

df.sample(5)
# Out:
#         plate                         Start Hub  \
# 1041  9140029          Arcadian Shopping Center
# 1174  9140019                       Nelson park
# 809   9140034                    C Town Markets
# 1286  9140020                    C Town Markets
# 745   9140016  Cronton Ave & Pleasantville Road
#
#                                End Hub        Date           Start Time  \
# 1041          Arcadian Shopping Center  2024-09-25  2024-09-25 10:50:45
# 1174               Metro North - Plaza  2024-09-03  2024-09-03 13:30:09
# 809                       Wishnie Park  2024-10-02   2024-10-02 0:22:16
# 1286                    C Town Markets  2024-09-06  2024-09-06 21:21:54
# 745   Cronton Ave & Pleasantville Road  2024-09-28  2024-09-28 20:42:55
#
#      Trip Durration  Billing Zip Code      Start Hub Geolocation  \
# 1041        0:26:54           10562.0   (41.1394616, -73.861803)
# 1174        0:07:34           10562.0  (41.1521048, -73.8623897)
# 809         1:50:18           10562.0   (41.1653387, -73.856297)
# 1286        1:21:56           10562.0   (41.1653387, -73.856297)
# 745         0:56:27           10562.0  (41.1669377, -73.8497735)
#
#             End Hub Geolocation
# 1041   (41.1394616, -73.861803)
# 1174    (41.157844, -73.868112)
# 809   (41.1607067, -73.8477673)
# 1286   (41.1653387, -73.856297)
# 745   (41.1669377, -73.8497735)

# %% [markdown]
# ## Save
# Save the merged trip and geolocation data to a new CSV file.

# %%
# Save to file
file_path = './data/all-trips-geo.csv'
file_path = Path(file_path).resolve() # make platform-agnostic
df.to_csv(file_path, index=False)

# %% [markdown]
# ## Quick map
# Put together a quick map to visualze all the trip data.

# %% [markdown]
# Count how many trips start and end at each hub combination.

# %%
# Group by 'Start Hub Geolocation' and 'End Hub Geolocation' and count occurrences
grouped_df = df.groupby(['Start Hub Geolocation', 'End Hub Geolocation']).size().reset_index(name='Count')
# Map geolocations to hub names using addresses_df
geo_to_hub = addresses_df.set_index('Geolocation')['Hub'].to_dict()

# Add 'Start Hub' and 'End Hub' columns with the names of the hubs
grouped_df['Start Hub'] = grouped_df['Start Hub Geolocation'].map(geo_to_hub)
grouped_df['End Hub'] = grouped_df['End Hub Geolocation'].map(geo_to_hub)

grouped_df.head()
# Out:
#       Start Hub Geolocation        End Hub Geolocation  Count  \
# 0  (41.1394616, -73.861803)   (41.1394616, -73.861803)     40
# 1  (41.1394616, -73.861803)  (41.1521048, -73.8623897)      8
# 2  (41.1394616, -73.861803)  (41.1570899, -73.8640002)      4
# 3  (41.1394616, -73.861803)    (41.157844, -73.868112)      8
# 4  (41.1394616, -73.861803)  (41.1593892, -73.8638232)     16
#
#                   Start Hub                   End Hub
# 0  Arcadian Shopping Center  Arcadian Shopping Center
# 1  Arcadian Shopping Center               Nelson park
# 2  Arcadian Shopping Center        Spring St, Cofield
# 3  Arcadian Shopping Center       Metro North - Plaza
# 4  Arcadian Shopping Center           Spring & Waller

# %%
# Add a new column 'One Hub' to indicate if 'Start Hub' and 'End Hub' are the same
grouped_df['Single Hub'] = grouped_df['Start Hub'] == grouped_df['End Hub']

grouped_df.sort_values(by='Count', inplace=True, ascending=False)
grouped_df.head(50)
# Out:
#          Start Hub Geolocation        End Hub Geolocation  Count  \
# 12   (41.1521048, -73.8623897)  (41.1521048, -73.8623897)    159
# 70   (41.1618223, -73.8629757)   (41.1394616, -73.861803)     86
# 57   (41.1607067, -73.8477673)  (41.1607067, -73.8477673)     86
# 34     (41.157844, -73.868112)    (41.157844, -73.868112)     78
# 23   (41.1570899, -73.8640002)  (41.1570899, -73.8640002)     59
# 14   (41.1521048, -73.8623897)    (41.157844, -73.868112)     58
# 100   (41.1653387, -73.856297)   (41.1653387, -73.856297)     48
# 76   (41.1618223, -73.8629757)  (41.1618223, -73.8629757)     47
# 111  (41.1669377, -73.8497735)  (41.1669377, -73.8497735)     46
# 7     (41.1394616, -73.861803)  (41.1618223, -73.8629757)     46
# 88   (41.1642872, -73.8604165)  (41.1642872, -73.8604165)     45
# 0     (41.1394616, -73.861803)   (41.1394616, -73.861803)     40
# 66   (41.1609922, -73.8627212)  (41.1609922, -73.8627212)     38
# 41     (41.157844, -73.868112)  (41.1669377, -73.8497735)     36
# 32     (41.157844, -73.868112)  (41.1521048, -73.8623897)     34
# 46   (41.1593892, -73.8638232)  (41.1593892, -73.8638232)     27
# 11   (41.1521048, -73.8623897)   (41.1394616, -73.861803)     22
# 62   (41.1609922, -73.8627212)   (41.1394616, -73.861803)     22
# 92    (41.1653387, -73.856297)  (41.1521048, -73.8623897)     19
# 38     (41.157844, -73.868112)  (41.1618223, -73.8629757)     17
# 42   (41.1593892, -73.8638232)   (41.1394616, -73.861803)     17
# 4     (41.1394616, -73.861803)  (41.1593892, -73.8638232)     16
# 105  (41.1669377, -73.8497735)    (41.157844, -73.868112)     15
# 21   (41.1570899, -73.8640002)   (41.1394616, -73.861803)     14
# 6     (41.1394616, -73.861803)  (41.1609922, -73.8627212)     14
# 80   (41.1642872, -73.8604165)   (41.1394616, -73.861803)     11
# 109  (41.1669377, -73.8497735)  (41.1642872, -73.8604165)     11
# 108  (41.1669377, -73.8497735)  (41.1609922, -73.8627212)     11
# 71   (41.1618223, -73.8629757)  (41.1521048, -73.8623897)     10
# 90   (41.1642872, -73.8604165)  (41.1669377, -73.8497735)     10
# 19   (41.1521048, -73.8623897)   (41.1653387, -73.856297)      9
# 8     (41.1394616, -73.861803)  (41.1642872, -73.8604165)      9
# 9     (41.1394616, -73.861803)   (41.1653387, -73.856297)      9
# 35     (41.157844, -73.868112)  (41.1593892, -73.8638232)      8
# 1     (41.1394616, -73.861803)  (41.1521048, -73.8623897)      8
# 3     (41.1394616, -73.861803)    (41.157844, -73.868112)      8
# 45   (41.1593892, -73.8638232)    (41.157844, -73.868112)      7
# 94    (41.1653387, -73.856297)    (41.157844, -73.868112)      7
# 31     (41.157844, -73.868112)   (41.1394616, -73.861803)      7
# 79   (41.1618223, -73.8629757)  (41.1669377, -73.8497735)      6
# 55   (41.1607067, -73.8477673)    (41.157844, -73.868112)      6
# 73   (41.1618223, -73.8629757)    (41.157844, -73.868112)      6
# 5     (41.1394616, -73.861803)  (41.1607067, -73.8477673)      6
# 69   (41.1609922, -73.8627212)  (41.1669377, -73.8497735)      6
# 68   (41.1609922, -73.8627212)   (41.1653387, -73.856297)      6
# 81   (41.1642872, -73.8604165)  (41.1521048, -73.8623897)      6
# 33     (41.157844, -73.868112)  (41.1570899, -73.8640002)      6
# 91    (41.1653387, -73.856297)   (41.1394616, -73.861803)      6
# 99    (41.1653387, -73.856297)  (41.1642872, -73.8604165)      6
# 24   (41.1570899, -73.8640002)    (41.157844, -73.868112)      6
#
#                             Start Hub                           End Hub  \
# 12                        Nelson park                       Nelson park
# 70       Municipal Parking Lot Lot# 7          Arcadian Shopping Center
# 57                       Wishnie Park                      Wishnie Park
# 34                Metro North - Plaza               Metro North - Plaza
# 23                 Spring St, Cofield                Spring St, Cofield
# 14                        Nelson park               Metro North - Plaza
# 100                    C Town Markets                    C Town Markets
# 76       Municipal Parking Lot Lot# 7      Municipal Parking Lot Lot# 7
# 111  Cronton Ave & Pleasantville Road  Cronton Ave & Pleasantville Road
# 7            Arcadian Shopping Center      Municipal Parking Lot Lot# 7
# 88            Ossining Public Library           Ossining Public Library
# 0            Arcadian Shopping Center          Arcadian Shopping Center
# 66                      Market Square                     Market Square
# 41                Metro North - Plaza  Cronton Ave & Pleasantville Road
# 32                Metro North - Plaza                       Nelson park
# 46                    Spring & Waller                   Spring & Waller
# 11                        Nelson park          Arcadian Shopping Center
# 62                      Market Square          Arcadian Shopping Center
# 92                     C Town Markets                       Nelson park
# 38                Metro North - Plaza      Municipal Parking Lot Lot# 7
# 42                    Spring & Waller          Arcadian Shopping Center
# 4            Arcadian Shopping Center                   Spring & Waller
# 105  Cronton Ave & Pleasantville Road               Metro North - Plaza
# 21                 Spring St, Cofield          Arcadian Shopping Center
# 6            Arcadian Shopping Center                     Market Square
# 80            Ossining Public Library          Arcadian Shopping Center
# 109  Cronton Ave & Pleasantville Road           Ossining Public Library
# 108  Cronton Ave & Pleasantville Road                     Market Square
# 71       Municipal Parking Lot Lot# 7                       Nelson park
# 90            Ossining Public Library  Cronton Ave & Pleasantville Road
# 19                        Nelson park                    C Town Markets
# 8            Arcadian Shopping Center           Ossining Public Library
# 9            Arcadian Shopping Center                    C Town Markets
# 35                Metro North - Plaza                   Spring & Waller
# 1            Arcadian Shopping Center                       Nelson park
# 3            Arcadian Shopping Center               Metro North - Plaza
# 45                    Spring & Waller               Metro North - Plaza
# 94                     C Town Markets               Metro North - Plaza
# 31                Metro North - Plaza          Arcadian Shopping Center
# 79       Municipal Parking Lot Lot# 7  Cronton Ave & Pleasantville Road
# 55                       Wishnie Park               Metro North - Plaza
# 73       Municipal Parking Lot Lot# 7               Metro North - Plaza
# 5            Arcadian Shopping Center                      Wishnie Park
# 69                      Market Square  Cronton Ave & Pleasantville Road
# 68                      Market Square                    C Town Markets
# 81            Ossining Public Library                       Nelson park
# 33                Metro North - Plaza                Spring St, Cofield
# 91                     C Town Markets          Arcadian Shopping Center
# 99                     C Town Markets           Ossining Public Library
# 24                 Spring St, Cofield               Metro North - Plaza
#
#      Single Hub
# 12         True
# 70        False
# 57         True
# 34         True
# 23         True
# 14        False
# 100        True
# 76         True
# 111        True
# 7         False
# 88         True
# 0          True
# 66         True
# 41        False
# 32        False
# 46         True
# 11        False
# 62        False
# 92        False
# 38        False
# 42        False
# 4         False
# 105       False
# 21        False
# 6         False
# 80        False
# 109       False
# 108       False
# 71        False
# 90        False
# 19        False
# 8         False
# 9         False
# 35        False
# 1         False
# 3         False
# 45        False
# 94        False
# 31        False
# 79        False
# 55        False
# 73        False
# 5         False
# 69        False
# 68        False
# 81        False
# 33        False
# 91        False
# 99        False
# 24        False

# %% [markdown]
# Calculate the min and max number of trips in the grouped data.

# %%
min_count = grouped_df['Count'].min()
max_count = grouped_df['Count'].max()

min_count, max_count
# Out:
# (np.int64(1), np.int64(159))

# %%
import folium

# Create a map centered on Ossining, NY
map = folium.Map(location=[41.162, -73.861], zoom_start=14, tiles='CartoDB dark_matter')

# Add circles for each unique hub
for _, row in addresses_df.iterrows():
    hub_coords = eval(row['Geolocation'])
    hub_name = row['Hub']
    # Count the number of rows with this location as 'Start Hub Geolocation'
    start_hub_count = df[df['Start Hub Geolocation'] == row['Geolocation']].shape[0]
    end_hub_count = df[df['End Hub Geolocation'] == row['Geolocation']].shape[0]
    same_hub_count = df[(df['Start Hub Geolocation'] == row['Geolocation']) & (df['End Hub Geolocation'] == row['Geolocation'])].shape[0]
    total_hub_count = start_hub_count + end_hub_count
    percent_same_hub = round((same_hub_count / total_hub_count) * 100)
    hub_popup = f"<h4>{hub_name}</h4><p><strong>{start_hub_count}</strong> trips started here</p><p><strong>{end_hub_count}</strong> trips ended here</p><p><strong>{percent_same_hub}%</strong> ({same_hub_count}) of these both started and ended here</p>"
    folium.CircleMarker(
        location=hub_coords,
        radius=5 + start_hub_count / 10,  # Base radius is 5, scaled by the count
        color='gray',
        fill=True,
        fill_color='black',
        fill_opacity=0.7,
        popup=folium.Popup(hub_popup, max_width=300, parse_html=False)
    ).add_to(map)


# Add lines for each trip
for _, row in grouped_df.iterrows():
    if pd.notnull(row['Start Hub Geolocation']) and pd.notnull(row['End Hub Geolocation']):
        start_coords = eval(row['Start Hub Geolocation'])
        end_coords = eval(row['End Hub Geolocation'])
        # start_coords = (start_coords[0] + 0.0005, start_coords[1] + 0.0005) # offset the start coords a bit to separate them from other lines going the other direction
        random_color = np.random.choice([
            'red', 'blue', 'green', 'purple', 'orange', 'yellow', 
            'pink', 'brown', 'cyan', 'magenta', 'lime', 'teal', 
            'indigo', 'violet', 'gold', 'silver', 'maroon', 'navy'
        ])
        line_weight = row['Count'] / 10  # Adjust the weight based on the count
        line = folium.PolyLine([start_coords, end_coords], color=random_color, weight=line_weight)
        # Add an arrowhead in the middle of the line, pointing towards the end
        mid_coords = ((start_coords[0] + end_coords[0]) / 2, (start_coords[1] + end_coords[1]) / 2)

        # a triangle pointing the direction of the trip
        offset_mid_coords = ((mid_coords[0] + start_coords[0]) / 2, (mid_coords[1] + start_coords[1]) / 2) # offset from midpoint to prevent overlap
        arrow_head = folium.RegularPolygonMarker(
            location=offset_mid_coords,
            number_of_sides=3,
            radius=8,
            color=None,
            fill=True,
            fill_color=random_color,
            rotation=45
        ).add_to(map)

        # a popup that shows the number of trips between the two hubs in this direction
        popup_text = f"<h4>{row['Start Hub']} -> {row['End Hub']}</h4><p><strong>{row['Count']}</strong> trips</p>"
        folium.Popup(popup_text, max_width=300, parse_html=False).add_to(line) # add to line
        folium.Popup(popup_text, max_width=300, parse_html=False).add_to(arrow_head) # add to arrow head too

        # add line to map
        line.add_to(map) # add line to map


# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c616682e046f149dc0c1e0de597b2617 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c616682e046f149dc0c1e0de597b2617&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c616682e046f149dc0c1e0de597b2617 = L.map(
#                 &quot;map_c616682e046f149dc0c1e0de597b2617&quot;,
#                 {
#                     center: [41.162, -73.861],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53ab3aa2fb35ba756c8f13c21fc06db9 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_53ab3aa2fb35ba756c8f13c21fc06db9.addTo(map_c616682e046f149dc0c1e0de597b2617);
#
#
#             var circle_marker_6444bd34e6d400d71ea393c43a08670b = L.circleMarker(
#                 [41.1394616, -73.861803],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 21.6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c616682e046f149dc0c1e0de597b2617);
#
#
#         var popup_2efac04c863cc0d0bf644397a5dafb39 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_3d00007dd6eaeacc0eb28d3a9589cf60 = $(`&lt;div id=&quot;html_3d00007dd6eaeacc0eb28d3a9589cf60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;Arcadian Shopping Center&lt;/h4&gt;&lt;p&gt;&lt;strong&gt;166&lt;/strong&gt; trips started here&lt;/p&gt;&lt;p&gt;&lt;strong&gt;228&lt;/strong&gt; trips ended here&lt;/p&gt;&lt;p&gt;&lt;strong&gt;10%&lt;/strong&gt; (40) of these both started and ended here&lt;/p&gt;&lt;/div&gt;`)[0];
#                 popup_2efac04c863cc0d0bf644397a5dafb39.setContent(html_3d00007dd6eaeacc0eb28d3a9589cf60);
#
#
#
#         circle_marker_6444bd34e6d400d71ea393c43a08670b.bindPopup(popup_2efac04c863cc0d0bf644397a5dafb39)
#         ;
#
#
#
#
#             var circle_marker_2630743b2b29e6ec832b8ab32398dd78 = L.circleMarker(
#                 [41.1653387, -73.856297],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c616682e046f149dc0c1e0de597b2617);
#
#
#         var popup_f8a56dc6bdd9870c20e0ea6f68bc9c53 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_47f9ee364c555f8eb2b41a87df58857b = $(`&lt;div id=&quot;html_47f9ee364c555f8eb2b41a87df58857b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;C Town Markets&lt;/h4&gt;&lt;p&gt;&lt;strong&gt;102&lt;/strong&gt; trips started here&lt;/p&gt;&lt;p&gt;&lt;strong&gt;94&lt;/strong&gt; trips ended here&lt;/p&gt;&lt;p&gt;&lt;strong&gt;24%&lt;/strong&gt; (48) of these both started and ended here&lt;/p&gt;&lt;/div&gt;`)[0];
#                 popup_f8a56dc6bdd9870c20e0ea6f68bc9c53.setContent(html_47f9ee364c555f8eb2b41a87df58857b);
#
#
#
#         circle_marker_2630743b2b29e6ec832b8ab32398dd78.bindPopup(popup_f8a56dc6bdd9870c20e0ea6f68bc9c53)
#         ;
#
#
#
#
#             var circle_marker_40f7a737617d46a67a96995805a2e854 = L.circleMarker(
#                 [41.1669377, -73.8497735],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 14.7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c616682e046f149dc0c1e0de597b2617);
#
#
#         var popup_749050e3f04f36c66c92d00a51593179 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_4ac8b9a9f181b28ddc875567

# %%
# Ensure the renders directory exists
renders_dir = Path('./renders').resolve()
renders_dir.mkdir(parents=True, exist_ok=True)

# Save the map to an HTML file in the renders directory
map_file_path = renders_dir / 'all-trips-map.html'
map.save(str(map_file_path))
